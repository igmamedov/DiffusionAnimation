# %%
# !pip install modelscope
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 34.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from modelscope.hub.snapshot_download import snapshot_download
model_dir = snapshot_download('iic/unianimate', cache_dir='checkpoints/')

# %%
template = "python3.9 -m run_align_pose --ref_name ../dataset/test/inference/sample_{n}/first_frame.png --source_video_paths ../dataset/test/inference/sample_{n}/orig_vid.mp4  --saved_pose_dir ../dataset/test/unianumate_poses/pose_{n} "

# %%
for i in range(0, 10):
    print(template.format(n=i))
    print('\n')
# Out:
# python3.9 -m run_align_pose --ref_name ../dataset/test/inference/sample_0/first_frame.png --source_video_paths ../dataset/test/inference/sample_0/orig_vid.mp4  --saved_pose_dir ../dataset/test/unianumate_poses/pose_0
#
#
# python3.9 -m run_align_pose --ref_name ../dataset/test/inference/sample_1/first_frame.png --source_video_paths ../dataset/test/inference/sample_1/orig_vid.mp4  --saved_pose_dir ../dataset/test/unianumate_poses/pose_1
#
#
# python3.9 -m run_align_pose --ref_name ../dataset/test/inference/sample_2/first_frame.png --source_video_paths ../dataset/test/inference/sample_2/orig_vid.mp4  --saved_pose_dir ../dataset/test/unianumate_poses/pose_2
#
#
# python3.9 -m run_align_pose --ref_name ../dataset/test/inference/sample_3/first_frame.png --source_video_paths ../dataset/test/inference/sample_3/orig_vid.mp4  --saved_pose_dir ../dataset/test/unianumate_poses/pose_3
#
#
# ...

# %%
template_ref = "../dataset/test/inference/sample_{n}/first_frame.png"
template_seq = "../dataset/test/unianumate_poses/pose_{n}"

for i in range(10):
    ref = template_ref.format(n=i)
    seq = template_seq.format(n=i)
    l = [1, ref, seq]
    print(l)
# Out:
# [1, '../dataset/test/inference/sample_0/first_frame.png', '../dataset/test/unianumate_poses/pose_0']
# [1, '../dataset/test/inference/sample_1/first_frame.png', '../dataset/test/unianumate_poses/pose_1']
# [1, '../dataset/test/inference/sample_2/first_frame.png', '../dataset/test/unianumate_poses/pose_2']
# [1, '../dataset/test/inference/sample_3/first_frame.png', '../dataset/test/unianumate_poses/pose_3']
# [1, '../dataset/test/inference/sample_4/first_frame.png', '../dataset/test/unianumate_poses/pose_4']
# [1, '../dataset/test/inference/sample_5/first_frame.png', '../dataset/test/unianumate_poses/pose_5']
# [1, '../dataset/test/inference/sample_6/first_frame.png', '../dataset/test/unianumate_poses/pose_6']
# [1, '../dataset/test/inference/sample_7/first_frame.png', '../dataset/test/unianumate_poses/pose_7']
# [1, '../dataset/test/inference/sample_8/first_frame.png', '../dataset/test/unianumate_poses/pose_8']
# ...
